# %% [markdown]
# # 随机测试

# %%
import os
import random

folder = '/Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/'
names = os.listdir(folder)
names = [name for name in names if name.endswith('.png')]
name = random.choice(names)
print(folder + name)

file_name = folder + name

import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread(file_name)  
plt.imshow(img)  
plt.show()
# Out:
# /Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/word_213.png

# %%
# !print $file_name
# !python demo.py --img_path $file_name
# Out:
# /Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/word_213.png
# loading pretrained model from ./expr/CRNN_499_50.pth
# ------------w--j----h------mm---f-------oo------- => wjhmfo
