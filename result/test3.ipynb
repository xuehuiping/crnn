# %% [markdown]
# 数据集`ICPR-MTWI-REC`，解压后为`/recognition/train/`

# %%
import os
import random

folder = './data/recognition/train/'
names = os.listdir(folder)
names = [name for name in names if name.endswith('.jpg')]
name = random.choice(names)
print(folder + name)

file_name = folder + name

import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread(file_name)  
plt.imshow(img)  
plt.show()
# Out:
# ./data/recognition/train/TB2mS5nm0hvOuFjSZFBXXcZgFXa_!!2654692376.jpg_13.jpg

# %%
# !print $file_name
# !python demo2.py --img_path $file_name --model_path expr2/CRNN_50.pth
# Out:
# Unescaped left brace in regex is deprecated, passed through in regex; marked by <-- HERE in m/%{ <-- HERE (.*?)}/ at /usr/bin/print line 528.
# Error: no "print" mailcap rules found for type "image/jpeg"
# loading pretrained model from expr2/CRNN_50.pth
# 从煜煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸煸 => 从煜煸

# %% [markdown]
# epoch=50
