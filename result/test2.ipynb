# %%
import os
import random

folder = '/Users/huihui/data/ocrinaction/ICPR-MTWI-REC/recognition/train/'
names = os.listdir(folder)
names = [name for name in names if name.endswith('.jpg')]
name = random.choice(names)
print(folder + name)

file_name = folder + name

import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread(file_name)  
plt.imshow(img)  
plt.show()
# Out:
# /Users/huihui/data/ocrinaction/ICPR-MTWI-REC/recognition/train/TB2AMcsXByN.eBjSZFIXXXbUVXa_!!28296792.jpg_1.jpg

# %%
# !print $file_name
# !python demo2.py --img_path $file_name
# Out:
# /Users/huihui/data/ocrinaction/ICPR-MTWI-REC/recognition/train/TB2AMcsXByN.eBjSZFIXXXbUVXa_!!28296792.jpg_1.jpg
# loading pretrained model from ./expr/test2/CRNN_38_8000.pth
# 微------------------------------------------凉----- => 微凉
