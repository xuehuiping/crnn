# %% [markdown]
# 训练数据集`ICDAR2013_REC.zip`, 解压后为`Challenge2_Training_Task3_Images_G`

# %%
import os
import random

folder = '/Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/'
names = os.listdir(folder)
names = [name for name in names if name.endswith('.png')]
name = random.choice(names)
print(folder + name)

file_name = folder + name

import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread(file_name)  
plt.imshow(img)  
plt.show()
# Out:
# /Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/word_526.png

# %%
# !print $file_name
# !python demo1.py --img_path $file_name --model_path expr1/CRNN_499_50.pth
# Out:
# /Users/huihui/data/ocrinaction/Challenge2_Training_Task3_Images_GT/word_526.png
# loading pretrained model from expr1/CRNN_499_50.pth
# ----f-------t---------t----------f--------s------ => fttfs
