# %% [markdown]
# 训练数据集`ICDAR2013_REC.zip`, 解压后为`Challenge2_Training_Task3_Images_G`

# %% [markdown]
# 训练
#
# ```
# python train.py \
# --trainroot ./data/Challenge2_Training_Task3_Images_GT/ \
# --valroot ./data/Challenge2_Training_Task3_Images_GT/ \
# --cuda \
# --expr_dir expr1_1220  >> log.train.1.12.20.txt &
#
# ```
#
# 后台运行

# %%
import os
import random

folder = './data/Challenge2_Training_Task3_Images_GT/'
names = os.listdir(folder)
names = [name for name in names if name.endswith('.png')]
name = random.choice(names)
print(folder + name)

file_name = folder + name

import matplotlib.pyplot as plt
# %matplotlib inline

img = plt.imread(file_name)  
plt.imshow(img)  
plt.show()
# Out:
# ./data/Challenge2_Training_Task3_Images_GT/word_635.png

# %%
# !print $file_name
# !python demo.py --img_path $file_name --model_path expr1/CRNN_485_50.pth
# Out:
# Unescaped left brace in regex is deprecated, passed through in regex; marked by <-- HERE in m/%{ <-- HERE (.*?)}/ at /usr/bin/print line 528.
# Error: no "print" mailcap rules found for type "image/png"
# loading pretrained model from expr1/CRNN_485_50.pth
# --------p------------------vv-----------------u-- => pvu
